# %%
from IPython.display import Image
Image(filename='Streaming.jpg')

# %%
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# %%
sc = SparkContext("local[2]","YouTubeDemo4")

# %%
# public StreamingContext(SparkConf conf, Duration batchDuration
# batchDuration - the time interval at which streaming data will be divided into batches
ssc = StreamingContext(sc, 10)

# %%
type(ssc)
# Out:
# pyspark.streaming.context.StreamingContext

# %%
# Create a DStream that will connect to hostname:port, like localhost:9999
lines = ssc.socketTextStream("localhost", 9999)

# %%
type(lines)
# Out:
# pyspark.streaming.dstream.DStream

# %%
# Split each line into words
words = lines.flatMap(lambda line: line.split(" "))

# %%
type(words)
# Out:
# pyspark.streaming.dstream.TransformedDStream

# %%
words.pprint()

# %%
ssc.start()             # Start the computation
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2020-06-15 02:40:10
# -------------------------------------------
# how
# are
# you?
#
# -------------------------------------------
# Time: 2020-06-15 02:40:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-06-15 02:40:30
# -------------------------------------------
# BINOD
# SUMAN
# ACADEMY
#
# -------------------------------------------
# Time: 2020-06-15 02:40:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-06-15 02:40:50
# -------------------------------------------
# PLEASE
# SUBSCRIBE
# THIS
# CHANNEL
#
# -------------------------------------------
# Time: 2020-06-15 02:41:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-06-15 02:41:10
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-42b1755e08bf> in <module>
#       1 ssc.start()             # Start the computation
# ----> 2 ssc.awaitTermination()
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/pyspark/streaming/context.py in awaitTermination(self, timeout)
#     190         """
#     191         if timeout is None:
# --> 192             self._jssc.awaitTermination()
#     193         else:
#     194             self._jssc.awaitTerminationOrTimeout(int(timeout * 1000))
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~/Documents/software/anaconda/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
sc.stop()

# %%
ssc.stop()
